# %%
import os
import io
import hashlib
import tarfile
import requests
from tqdm import tqdm


from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_data = "/content/drive/MyDrive/Modeling Satelities Images Building Damaged/data/"
path_data
# Out:
# '/content/drive/MyDrive/Modeling Satelities Images Building Damaged/data/'

# %%
urls = [
  ("https://download.xview2.org/hold_images_labels_targets.tar.gz?Expires=1679610417&Signature=JmpO-fzoJt7E2Gr8h4~09tTwKnl35WquYWwfTO1JVhA5jsyVmVpZZqUYDzxZXqO5S9pO~8K8ZjNEBPEW1QvOGmXeFKRIswClOs3dtDd8agZkwYtWdKPella4aGqxqUeIJq67CSiPRaVDLsfPOum~wmwUQ2JIS~AkGD-5wm5rSaFg5Zq5QaPqzrFHtY2fxi8Pwx5zFwGCwhbjtGr37qcZH97Bi~hb5lFKHrSWsY4i9Kp1q7RaEh50v-vw6Rgw9ZjDB6u6ErKaqxv9BOVw~lraCiRnGjMZA~kmw4-GtrO4Y8jhGOrKozM8L-nl1XCM49RhmfW77RVgEGlQiwq95WVGbQ__&Key-Pair-Id=APKAIKGDJB5C3XUL2DXQ", "fe7f162f0895bfaff134cab3abc23872f38d17da"),
]

# %% [markdown]
# # Download data

# %%
for url, sha1 in tqdm(urls):
  response = requests.get(url)
  if hashlib.sha1(response.content).hexdigest() == sha1:
    nome_arquivo = url.split("/")[-1].split("?")[0] # obter o nome do arquivo a partir do URL
    path_completo = path_data + nome_arquivo # adicionar o nome do arquivo ao caminho do diretório

    with open(path_completo, 'wb') as f:
      f.write(response.content)
    print(f"Arquivo {nome_arquivo} baixado e salvo no diretório {path_data}.")
  else:
    print(f"O hash SHA1 do arquivo {nome_arquivo} está incorreto. O download falhou.")
# Out:
# 100%|██████████| 1/1 [02:38<00:00, 158.39s/it]
# Arquivo hold_images_labels_targets.tar.gz baixado e salvo no diretório /content/drive/MyDrive/Modeling Satelities Images Building Damaged/data/.

# %% [markdown]
# #Descompres data

# %%
tar_path = "/content/drive/MyDrive/Modeling Satelities Images Building Damaged/data/train_images_labels_targets.tar.gz"

# %%
with tarfile.open(tar_path, "r:gz") as tar:
    tar.extractall(path="/content/drive/MyDrive/Modeling Satelities Images Building Damaged/data/")

# %%
print(len(os.listdir(path_data+'train/targets/')))
print(len(os.listdir(path_data+'train/images/')))
print(len(os.listdir(path_data+'train/labels/')))
# Out:
# 5598
# 5598
# 5598

# %%
tar_path = "/content/drive/MyDrive/Modeling Satelities Images Building Damaged/data/test_images_labels_targets.tar.gz"

# %%
with tarfile.open(tar_path, "r:gz") as tar:
    tar.extractall(path="/content/drive/MyDrive/Modeling Satelities Images Building Damaged/data/")

# %%
print(len(os.listdir(path_data+'test/targets/')))
print(len(os.listdir(path_data+'test/images/')))
print(len(os.listdir(path_data+'test/labels/')))
# Out:
# 1866
# 1839
# 1866

# %%
tar_path = "/content/drive/MyDrive/Modeling Satelities Images Building Damaged/data/hold_images_labels_targets.tar.gz"

# %%
with tarfile.open(tar_path, "r:gz") as tar:
    tar.extractall(path="/content/drive/MyDrive/Modeling Satelities Images Building Damaged/data/")

# %%
print(len(os.listdir(path_data+'hold/targets/')))
print(len(os.listdir(path_data+'hold/images/')))
print(len(os.listdir(path_data+'hold/labels/')))
# Out:
# 1866
# 1866
# 1866

# %%
tar_path = "/content/drive/MyDrive/Modeling Satelities Images Building Damaged/data/tier3.tar.gz"

# %%
with tarfile.open(tar_path, "r:gz") as tar:
    tar.extractall(path="/content/drive/MyDrive/Modeling Satelities Images Building Damaged/data/")

# %%
#print(len(os.listdir('/content/drive/MyDrive/Modeling Satelities Images Building Damaged/data/tier3/targets/')))
print(len(os.listdir(path_data+'/tier3/images/')))
print(len(os.listdir(path_data+'/tier3/labels/')))
# Out:
# 12726
# 12738

# %%
import pandas as pd
pd.DataFrame(os.listdir(path_data+'train/targets/'), columns=["x"]).query("x == 'guatemala-volcano_00000001_post_disaster.png'")
# Out:
# Empty DataFrame
# Columns: [x]
# Index: []

# %%
while True:
  a = 1
